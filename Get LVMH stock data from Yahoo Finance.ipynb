# %% [markdown]
# # Get LVMH stock data from Yahoo finance (from Python library : yfinance)

# %%
# make sure to install Yahoo Finance library
# you can use pip command in Conda prompt such as : pip install yfinance --upgrade --no-cache-dir

import yfinance as yf
import matplotlib.pyplot as plt
import seaborn
import pandas as pd

# %%
# use the LVMH ticker

LVMHstock = yf.Ticker("MC.PA")
print(LVMHstock.info)
# Out:
# {'zip': '75008', 'sector': 'Consumer Cyclical', 'fullTimeEmployees': 163309, 'longBusinessSummary': "LVMH MoÃ«t Hennessy - Louis Vuitton, SociÃ©tÃ© EuropÃ©enne operates as a luxury products company. The company offers champagnes, wines, and spirits under the Ao Yun, Ardbeg, Belvedere, Bodega Numanthia, Cape Mentelle, Chandon, ChÃ¢teau Cheval Blanc, ChÃ¢teau d'Yquem, Cheval des Andes, Clos des Lambrays, Clos19, Cloudy Bay, Dom PÃ©rignon, Glenmorangie, Hennessy, Krug, Mercier, MoÃ«t & Chandon, Newton, Vineyard, Ruinart, Terrazas de los Andes, Veuve Clicquot, Volcan de mi Tierra, and Woodinville brands. It also provides fashion and leather products under the Berluti, Celine, Christian Dior, Emilio Pucci, Fendi, Givenchy, Kenzo, Loewe, Loro Piana, Louis Vuitton, Marc Jacobs, Moynat, Nicholas Kirkwood, Pink Shirtmaker, and Rimowa brands. In addition, the company offers perfumes and cosmetics under the Acqua di Parma, Benefit Cosmetics, Fenty Beauty by Rihanna, Fresh, Parfums Givenchy, Guerlain, Kat Von D Beauty, Kenzo Parfums, Maison Francis Kurkdjian, Make Up For Ever, Marc Jacobs Beauty, Parfums Christian Dior, and Perfumes Loewe brands; watches and jewelry under the Bvlgari, Chaumet, Fred, Hublot, TAG Heuerand Zenith brands; and custom-designed yachts under the Feadship brand name, as well as designs and builds luxury yachts under the Royal Van Lent brand. Further, it provides daily newspapers under the Les Ã\x89chos brand; Belmond, a luxury tourism service; home other activities under the Belmond, Cheval Blanc, Connaissance des Arts, Cova, Investir, Jardin d'Acclimatation, La Samaritaine, Le Parisien, and Radio Classique brands; and selective retailing products under the DFS, La Grande Epicerie de Paris, Le Bon MarchÃ© Rive Gauche, Sephora, and Starboard Cruise brands, as well as operates Jardin d'Acclimatation, a leisure and amusement park. As of December 31, 2019, the company operated 4,915 stores worldwide. The company was incorporated in 1923 and is headquartered in Paris, France.", 'city': 'Paris', 'phone': '33 1 44 13 22 22', 'country': 'France', 'companyOfficers': [], 'website': 'http://www.lvmh.com', 'maxAge': 1, 'address1': '22, Avenue Montaigne', 'fax': '33 1 44 13 22 23', 'industry': 'Luxury Goods', 'previousClose': 499.65, 'regularMarketOpen': 502.1, 'twoHundredDayAverage': 436.9708, 'trailingAnnualDividendYield': 0.009206444, 'payoutRatio': 0.5461, 'volume24Hr': None, 'regularMarketDayHigh': 502.8, 'navPrice': None, 'averageDailyVolume10Day': 428095, 'totalAssets': None, 'regularMarketPreviousClose': 499.65, 'fiftyDayAverage': 503.79395, 'trailingAnnualDividendRate': 4.6, 'open': 502.1, 'toCurrency': None, 'averageVolume10days': 428095, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': 4.6, 'exDividendDate': 1606780800, 'beta': 0.841675, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 489.05, 'priceHint': 2, 'currency': 'EUR', 'trailingPE': 55.902775, 'regularMarketVolume': 468063, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 247438131200, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 478957, 'priceToSalesTrailing12Months': 5.26677, 'dayLow': 489.05, 'ask': 0, 'ytdReturn': None, 'askSize': 0, 'volume': 468063, 'fiftyTwoWeekHigh': 525.3, 'forwardPE': 35.32734, 'fromCurrency': None, 'fiveYearAvgDividendYield': 1.76, 'fiftyTwoWeekLow': 278.7, 'bid': 0, 'tradeable': False, 'dividendYield': 0.0092, 'bidSize': 0, 'dayHigh': 502.8, 'exchange': 'PAR', 'shortName': 'LVMH', 'longName': 'LVMH Moët Hennessy - Louis Vuitton, Société Européenne', 'exchangeTimezoneName': 'Europe/Paris', 'exchangeTimezoneShortName': 'CET', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '3600000', 'quoteType': 'EQUITY', 'symbol': 'MC.PA', 'messageBoardId': 'finmb_195488', 'market': 'fr_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 5.761, 'beta3Year': None, 'profitMargins': 0.094189994, 'enterpriseToEbitda': 28.158, '52WeekChange': 0.17995 ...

# %%
# we convert these data into a Pandas dataframe to export in CSV/Excel

LVMHdata=LVMHstock.info
LVMHdataN=pd.DataFrame.from_dict(LVMHdata, orient ='index')  
LVMHdataN.reset_index(inplace=True)  
LVMHdataN.rename(columns = {'index':'Information', 0:'Valeur'}, inplace = True) 
print(LVMHdataN)
# Out:
#                   Information  \
# 0                         zip
# 1                      sector
# 2           fullTimeEmployees
# 3         longBusinessSummary
# 4                        city
# ..                        ...
# 118  impliedSharesOutstanding
# 119                  category
# 120     fiveYearAverageReturn
# 121        regularMarketPrice
# 122                  logo_url
#
#                                                 Valeur
# 0                                                75008
# 1                                    Consumer Cyclical
# 2                                               163309
# 3    LVMH MoÃ«t Hennessy - Louis Vuitton, SociÃ©tÃ©...
# 4                                                Paris
# ..                                                 ...
# 118                                               None
# 119                                               None
# 120                                               None
# 121                                              502.1
# 122                 https://logo.clearbit.com/lvmh.com
#
# [123 rows x 2 columns]

# %%
# get the last 10 years of the stock performance - 

hist = LVMHstock.history(period="10y")
hist = pd.DataFrame(hist)
hist.reset_index(inplace=True)  
print(hist)
# Out:
#            Date        Open        High         Low       Close   Volume  \
# 0    2011-01-19   96.254824   96.700638   92.445162   92.728859  1390049
# 1    2011-01-20   93.377301   93.377301   89.891868   91.431946  1700348
# 2    2011-01-21   91.594051   92.323563   90.661898   91.026657  1355025
# 3    2011-01-24   91.391420   92.283043   90.459267   91.837234   854813
# 4    2011-01-25   92.323573   94.795799   92.161456   93.742065  1111953
# ...         ...         ...         ...         ...         ...      ...
# 2550 2021-01-13  517.200012  520.299988  510.299988  512.099976   317983
# 2551 2021-01-14  513.400024  515.200012  508.000000  508.000000   446027
# 2552 2021-01-15  506.000000  508.200012  492.450012  493.950012   692278
# 2553 2021-01-18  494.000000  501.899994  494.000000  499.649994   342930
# 2554 2021-01-19  502.100006  502.799988  489.049988  491.049988   468063
#
#       Dividends  Stock Splits
# 0           0.0             0
# 1           0.0             0
# 2           0.0             0
# 3           0.0             0
# 4           0.0             0
# ...         ...           ...
# 2550        0.0             0
# 2551        0.0             0
# 2552        0.0             0
# 2553        0.0             0
# 2554        0.0             0
#
# [2555 rows x 8 columns]

# %%
# to ensure that the data are a pandas dataframe, use the function type()

print(type(hist))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# how to get most recent stock price - use 1d parameter

hist2 = LVMHstock.history(period="1d")
hist2 = pd.DataFrame(hist2)
hist2.reset_index(inplace=True)  
print(hist2)
# Out:
#         Date        Open        High         Low       Close  Volume  \
# 0 2021-01-19  502.100006  502.799988  489.049988  491.049988  468063
# 1 2021-01-19  502.100006  502.799988  489.049988  491.049988  468063
#
#    Dividends  Stock Splits
# 0          0             0
# 1          0             0

# %%
# quickly get an idea of the stock price evolution using Matplotlib library

hist['Close'].plot(figsize=(16, 9))
# Out:
# <AxesSubplot:>

# %%
# get next events using the Calendar

LVMHstock.calendar
# Out:
#                       Value
# Earnings Date    2021-01-26
# Earnings Average        NaT
# Earnings Low            NaT
# Earnings High           NaT
# Revenue Average         NaT
# Revenue Low             NaT
# Revenue High            NaT

# %%
# download stock price data and save these in a CSV file via Jupyter Notebook

hist_df = yf.download("MC.PA", start="2020-02-01", end="2020-03-20")
hist_df.to_csv('LVMH stock data.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# imprimer en CSV et stockage dans le PC

LVMHdataN_csv_data = LVMHdataN.to_csv('LVMHdataN.csv', index = True) 
print('\nCSV String:\n', LVMHdataN_csv_data)
# Out:
# CSV String:
#  None
